# %%
import subprocess
from pathlib import Path

from tqdm import tqdm

# %%
# %load_ext autoreload
# %autoreload 2
import bnpm

# %% [markdown]
# Get dates

# %%
path_tca_all     = r'/media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/fr_run/factors_refit_bigTCA.h5'

path_ws_outer          = r'/media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/wavesurfer_files/'
path_csv_outer         = r'/media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/cam4_CSVs/'
path_idxLaserCam_outer = r'/media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/eye_laser_trace_extraction/'
path_vqt_outer         = r'/media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/fr_run/'

# %%
paths_ws_all_raw = bnpm.path_helpers.find_paths(
    dir_outer=path_ws_outer,
    reMatch=r'exp.*h5',
    depth=4,
)
dates_ws_all = [Path(p).parts[-2] for p in paths_ws_all_raw]
paths_ws_all = {date: path for date, path in zip(dates_ws_all, paths_ws_all_raw)}

print(dates_ws_all)
# Out:
# ['20230702', '20230703', '20230705', '20230706', '20230707', '20230708', '20230709', '20230710', '20230711', '20230712', '20230713', '20230714', '20230715', '20230716', '20230717', '20230718', '20230719', '20230720', '20230721', '20230722', '20230723', '20230724', '20230725', '20230726', '20230727', '20230728', '20230729', '20230730', '20230731', '20230801', '20230802', '20230803', '20230804', '20230805', '20230806', '20230807', '20230808', '20230809', '20230810', '20230811']

# %%
paths_csv_all_raw = bnpm.path_helpers.find_paths(
    dir_outer=path_csv_outer,
    reMatch=r'times.*csv',
    depth=4,
)
dates_csv_all = [Path(p).parts[-2] for p in paths_csv_all_raw]
paths_csv_all = {date: path for date, path in zip(dates_csv_all, paths_csv_all_raw)}

print(dates_csv_all)
# Out:
# ['20230703', '20230705', '20230706', '20230707', '20230708', '20230709', '20230710', '20230711', '20230712', '20230713', '20230714', '20230715', '20230716', '20230717', '20230718', '20230719', '20230720', '20230721', '20230722', '20230723', '20230724', '20230725', '20230726', '20230727', '20230728', '20230729', '20230730', '20230731', '20230801', '20230802', '20230803', '20230804', '20230805', '20230806', '20230807', '20230808', '20230809', '20230811']

# %%
paths_idxLaserCam_all_raw = bnpm.path_helpers.find_paths(
    dir_outer=path_idxLaserCam_outer,
    reMatch=r'idx_eye_laser\.pkl',
    depth=6,
)
dates_idxLaserCam_all = [Path(p).parts[-3] for p in paths_idxLaserCam_all_raw]
paths_idxLaserCam_all = {date: path for date, path in zip(dates_idxLaserCam_all, paths_idxLaserCam_all_raw)}

print(dates_idxLaserCam_all)
# Out:
# ['20230703', '20230705', '20230706', '20230707', '20230708', '20230709', '20230710', '20230711', '20230712', '20230713', '20230714', '20230715', '20230716', '20230717', '20230718', '20230719', '20230720', '20230721', '20230722', '20230723', '20230724', '20230725', '20230726', '20230727', '20230728', '20230729', '20230730', '20230731', '20230801', '20230802', '20230803', '20230804', '20230805', '20230806', '20230807', '20230808', '20230809', '20230811']

# %%
paths_vqt_all_raw = bnpm.path_helpers.find_paths(
    dir_outer=path_vqt_outer,
    reMatch=r'VQT_Analyzer\.h5',
    depth=4,
)
dates_vqt_all = [Path(p).parts[-4] for p in paths_vqt_all_raw]
paths_vqt_all = {date: path for date, path in zip(dates_vqt_all, paths_vqt_all_raw)}

print(dates_vqt_all)
# Out:
# ['20230703', '20230705', '20230706', '20230707', '20230708', '20230709', '20230710', '20230711', '20230712', '20230713', '20230714', '20230715', '20230716', '20230717', '20230718', '20230719', '20230720', '20230721', '20230722', '20230723', '20230724', '20230725', '20230726', '20230727', '20230728', '20230729', '20230730', '20230731', '20230801', '20230802', '20230803', '20230804', '20230805', '20230806', '20230807', '20230808', '20230809', '20230811']

# %%
factors_refit_bigTCA = bnpm.h5_handling.simple_load(path_tca_all)

# %%
dates_toUse = factors_refit_bigTCA.keys()

# %%
dates_toUse
# Out:
# dict_keys(['20230703', '20230705', '20230706', '20230707', '20230708', '20230709', '20230710', '20230711', '20230712', '20230713', '20230714', '20230715', '20230716', '20230717', '20230718', '20230719', '20230720', '20230721', '20230722', '20230723', '20230724', '20230725', '20230726', '20230727', '20230728', '20230729', '20230730', '20230731', '20230801', '20230802', '20230803', '20230804', '20230805', '20230806', '20230807', '20230808', '20230809', '20230811'])

# %% [raw]
# DEMO:
#
# cmd = f"python \
# /media/rich/Home_Linux_partition/github_repos/NBAP/behavioral_drift_analysis/4a4_align_tca_and_ws_to_SI/align_tca_and_ws_to_SI.py \
# --path_ws /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0322R/wavesurfer_files/{date}/exp_0001.h5 \
# --path_csv /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0322R/cam4_CSVs/20230425/times_cam42023-04-25T11_06_59.csv \
# --path_tca_all /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0322R/fr_run/factors_refit_bigTCA.h5 \
# --path_idxLaserCam /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0322R/eye_laser_trace_extraction/{date}/jobNum_0/idx_eye_laser.pkl \
# --path_vqt /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0322R/fr_run/{date}/jobNum_0/analysis_files/VQT_Analyzer.h5 \
# --directory_save /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0322R/ws_and_tca__idx_SI/{date} \
# "

# %%
for date in tqdm(list(dates_toUse)[:]):
    
    cmd = f"python \
    /media/rich/Home_Linux_partition/github_repos/NBAP/behavioral_drift_analysis/4a4_align_tca_and_ws_to_SI/align_tca_and_ws_to_SI.py \
    --path_ws {paths_ws_all[date]} \
    --path_csv {paths_csv_all[date]} \
    --path_tca_all {path_tca_all} \
    --path_idxLaserCam {paths_idxLaserCam_all[date]} \
    --path_vqt {paths_vqt_all[date]} \
    --directory_save /media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/ws_and_tca__idx_SI/{date} \
    "
    subprocess.run(cmd, shell=True)
    # print(cmd)
# Out:
#   0%|                                                                                                                                                                                                               | 0/38 [00:00<?, ?it/s]
# ==== Loading h5 file "/media/rich/bigSSD/analysis_data/face_rhythm/mouse_0403L/wavesurfer_files/20230703/exp_0001.h5" ====
# 1. header:----------------
#   1. AIChannelNames:    shape=(7,) ,        dtype=|S15
#   2. AITerminalIDsOnDevice:    shape=(8, 1) ,      dtype=float64
#   3. AOChannelNames:    shape=(1,) ,        dtype=object
#   4. AbsoluteProtocolFileName:    shape=(1,) ,        dtype=|S68
#   5. AbsoluteUserSettingsFileName:    shape=(1,) ,        dtype=object
#   6. Acquisition:----------------
#     1. ActiveChannelIndexFromChannelIndex:    shape=(7, 1) ,      dtype=float64
#     2. ActiveChannelNames:    shape=(7,) ,        dtype=|S15
#     3. AnalogChannelNames:    shape=(7,) ,        dtype=|S15
# ...
