# %%
import time
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import psutil
from psutil import cpu_percent
from psutil import virtual_memory
import numpy as np

# %%
# %matplotlib notebook

# %%
frame_len = 200
y = []
mem = []
def animate(i):
    y.append(cpu_percent())
    mem.append(virtual_memory().percent)
    
    if len(y) <= frame_len:
        plt.cla()
        plt.plot(y, 'r', label = 'Real-Time CPU Uses')
        plt.plot(mem, 'b', label='mem %')
        
    else:
        y.pop(0), mem.pop(0)
        plt.cla()
        plt.plot(y[-frame_len:], 'r', label = 'Real-Time CPU Uses')
        plt.plot(mem, 'b', label='mem %')

    plt.ylim(0,100)
    plt.xlabel('Time (frames)')
    plt.ylabel('CPU Uses (%)')
    plt.legend(loc = 'upper right')
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate, interval=50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/rh183/miniconda3/envs/fr_env/lib/python3.8/site-packages/matplotlib/animation.py:889: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
import resource

# %%
[resource.getrusage(ii) for ii in range(2)]
# Out:
# [resource.struct_rusage(ru_utime=10.109377, ru_stime=3.369107, ru_maxrss=176688, ru_ixrss=0, ru_idrss=0, ru_isrss=0, ru_minflt=113209, ru_majflt=1, ru_nswap=0, ru_inblock=4672, ru_oublock=4128, ru_msgsnd=0, ru_msgrcv=0, ru_nsignals=0, ru_nvcsw=67772, ru_nivcsw=220457),
#  resource.struct_rusage(ru_utime=8.103044, ru_stime=1.804943, ru_maxrss=176688, ru_ixrss=0, ru_idrss=0, ru_isrss=0, ru_minflt=109638, ru_majflt=1, ru_nswap=0, ru_inblock=2328, ru_oublock=120, ru_msgsnd=0, ru_msgrcv=0, ru_nsignals=0, ru_nvcsw=41518, ru_nivcsw=69)]
