# %% [markdown]
# You probably need around >=25GB for a session with ~4800 ROIs and a FOV=(512,1024)

# %%
# widen jupyter notebook window
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:95% !important; }</style>"))

# check environment
import os
print(f'Conda Environment: ' + os.environ['CONDA_DEFAULT_ENV'])
# Out:
# <style>.container {width:95% !important; }</style>
# Conda Environment: rapids-0.19

# %%
from pathlib import Path
import scipy.io
import scipy.sparse
import matplotlib.pyplot as plt
import numpy as np
import sklearn.manifold
import sklearn.cluster
import gc
import cv2
from tqdm.notebook import tqdm
import copy

# %%
import sys
# sys.path.append("/n/data1/hms/neurobio/sabatini/rich/github_repos/")
sys.path.append("/media/rich/Home_Linux_partition/github_repos/")

# %load_ext autoreload
# %autoreload 2
from basic_neural_processing_modules import *

# %%
# dir_allOuterFolders = Path("/n/data1/hms/neurobio/sabatini/rich/data/res2p/round_5_experiments/mouse_2_6/scanimage/")
dir_allOuterFolders = Path("/media/rich/bigSSD/res2p/scanimage data/round 5 experiments/mouse 2_6/just_stat_files")
pathSuffixToStat = "stat.npy"
pathSuffixToOps = "ops.npy"

paths_allOuterFolders, pathContents, pathNumerics = path_helpers.get_numeric_contents(dir_allOuterFolders, sort=True)

paths_allOuterFolders = paths_allOuterFolders[2:-1]
pathContents = pathContents[2:-1]
pathNumerics = pathNumerics[2:-1]

# paths_allOuterFolders = paths_allOuterFolders[2:3]
# pathContents = pathContents[2:3]
# pathNumerics = pathNumerics[2:3]

# %%
paths_allStat = [path / pathSuffixToStat for path in paths_allOuterFolders]

# %% [markdown]
# ## Make spatial_footprints
# Make a lazy list of all the spatial_footprints

# %%
sf_all = ca2p_preprocessing.import_and_convert_to_CellReg_spatialFootprints(paths_allStat, frame_height=512, frame_width=1024)

# %% [markdown]
# ## Save spatial_footprints as sparse matrices
# I hate this code, but it's necessary to remain low(ish) memory when saving

# %%
def register_FOVs(templateFOV, FOVs, ROIs, return_sparse=False):
    dims = templateFOV.shape
    x_grid, y_grid = np.meshgrid(np.arange(0., dims[1]).astype(np.float32), np.arange(0., dims[0]).astype(np.float32))

    template_norm = np.uint8(templateFOV * (templateFOV > 0) * 255)
    
    for ii in range(len(FOVs)):
        FOV_norm = np.uint8(FOVs[ii] * (FOVs[ii] > 0) * 255)
        flow = cv2.calcOpticalFlowFarneback(np.uint8(template_norm * 255), np.uint8(FOV_norm * 255), None,
                                            0.5, 3, 128, 3, 7, 1.5, 0)
        x_remap = (flow[:, :, 0] + x_grid).astype(np.float32)
        y_remap = (flow[:, :, 1] + y_grid).astype(np.float32)

        # A_2t = np.reshape(A2, dims + (-1,), order='F').transpose(2, 0, 1)
#         A_2t = sf_all[6]
        ROI_aligned = np.stack([cv2.remap(img.astype(np.float32), x_remap, y_remap, cv2.INTER_NEAREST) for img in ROIs[ii]], axis=0)
        # A2 = np.reshape(A2.transpose(1, 2, 0), (A1.shape[0], A_2t.shape[0]), order='F')
        
        if return_sparse:
            yield scipy.sparse.csc_matrix(ROI_aligned.reshape(ROI_aligned.shape[0], -1))
        else:
            yield ROI_aligned

# %% [raw]
# ops = [np.load(path / pathSuffixToOps, allow_pickle=True)[()] for path in paths_allOuterFolders]
#
# meanIms = [ops[ii]['meanImgE'] for ii in range(len(ops))]

# %% [raw]
# ROIs_aligned = list(register_FOVs(meanIms[0], meanIms, sf_all, return_sparse=True))

# %% [raw]
# np.savez_compressed('/media/rich/bigSSD/analysis_data/mouse 2_6/multiday_alignment/ROIs_aligned.npz', tuple(ROIs_aligned))

# %%
ROIs_aligned = np.load('/media/rich/bigSSD/analysis_data/mouse 2_6/multiday_alignment/ROIs_aligned.npz', allow_pickle=True)['arr_0']

# %%
def make_block_batches(
    frame_height=512,
    frame_width=1024,
    block_height=100,
    block_width=100,
    overlap_tileMultiplier=2,
    inner_block_height=None,
    inner_block_width=None,
):     
    
    # block prep
    block_height_half = block_height//2
    block_width_half = block_width//2
    
    # inner block prep
    if inner_block_height is None:
        inner_block_height = block_height * 0.5
    if inner_block_width is None:
        inner_block_width = block_width * 0.5
        
    inner_block_height_half = inner_block_height//2
    inner_block_width_half = inner_block_width//2
    
    # find centers of blocks
    n_blocks_x = frame_width / block_width
    n_blocks_x = np.ceil(n_blocks_x*overlap_tileMultiplier).astype(np.int64)
    centers_x = np.linspace(
        start=block_width_half,
        stop=frame_width - block_width_half,
        num=n_blocks_x,
        endpoint=True
    )

    n_blocks_y = frame_height / block_height
    n_blocks_y = np.ceil(n_blocks_y*overlap_tileMultiplier).astype(np.int64)
    centers_y = np.linspace(
        start=block_height_half,
        stop=frame_height - block_height_half,
        num=n_blocks_y,
        endpoint=True
    )
    
    # make blocks
    blocks, inner_blocks = [], []
    for i_x in range(n_blocks_x):
        for i_y in range(n_blocks_y):
            blocks.append([
                list(np.int64([centers_y[i_y] - block_height_half , centers_y[i_y] + block_height_half])),
                list(np.int64([centers_x[i_x] - block_width_half , centers_x[i_x] + block_width_half]))
            ])
            
            inner_blocks.append([
                list(np.int64([centers_y[i_y] - inner_block_height_half , centers_y[i_y] + inner_block_height_half])),
                list(np.int64([centers_x[i_x] - inner_block_width_half , centers_x[i_x] + inner_block_width_half]))                
            ])
    return blocks, inner_blocks, (centers_y, centers_x)

# %%
blocks, inner_blocks, centers = make_block_batches(
    frame_height=512,
    frame_width=1024,
    block_height=200,
    block_width=200,
    overlap_tileMultiplier=1.2,
    inner_block_height=150,
    inner_block_width=150,
)
inner_blocks
# Out:
# [[[25, 175], [25, 175]],
#  [[129, 279], [25, 175]],
#  [[233, 383], [25, 175]],
#  [[337, 487], [25, 175]],
#  [[25, 175], [162, 312]],
#  [[129, 279], [162, 312]],
#  [[233, 383], [162, 312]],
#  [[337, 487], [162, 312]],
#  [[25, 175], [299, 449]],
#  [[129, 279], [299, 449]],
#  [[233, 383], [299, 449]],
#  [[337, 487], [299, 449]],
#  [[25, 175], [437, 587]],
#  [[129, 279], [437, 587]],
#  [[233, 383], [437, 587]],
#  [[337, 487], [437, 587]],
#  [[25, 175], [574, 724]],
#  [[129, 279], [574, 724]],
#  [[233, 383], [574, 724]],
#  [[337, 487], [574, 724]],
#  [[25, 175], [711, 861]],
#  [[129, 279], [711, 861]],
#  [[233, 383], [711, 861]],
#  [[337, 487], [711, 861]],
#  [[25, 175], [849, 999]],
#  [[129, 279], [849, 999]],
#  [[233, 383], [849, 999]],
#  [[337, 487], [849, 999]]]

# %% [markdown]
# set parameters

# %%
import cuml
import cuml.manifold

# %%
frame_height=512
frame_width=1024
block_height=200
block_width=200
overlap_tileMultiplier=1.2
inner_block_height=150
inner_block_width=150

blocks, inner_blocks, centers = make_block_batches(
    frame_height=frame_height,
    frame_width=frame_width,
    block_height=block_height,
    block_width=block_width,
    overlap_tileMultiplier=overlap_tileMultiplier,
    inner_block_height=inner_block_height,
    inner_block_width=inner_block_width,
)

tsne = sklearn.manifold.TSNE(
    n_components=2,
    perplexity=200.0,
    early_exaggeration=5.0,
    learning_rate=200.0,
    n_iter=1000,
    n_iter_without_progress=300,
    min_grad_norm=1e-07,
#     metric='euclidean',
    metric='precomputed',
#     init='pca',
    init='random',
    verbose=3,
    random_state=None,
    method='barnes_hut',
    angle=0.5,
    n_jobs=-1,
    square_distances=True,
)

# tsne = cuml.manifold.TSNE(
#     n_components=2,
#     perplexity=10.0,
#     early_exaggeration=12.0,
#     learning_rate=200.0,
#     n_iter=300,
#     n_iter_without_progress=300,
#     min_grad_norm=1e-07,
#     metric='euclidean',
#     init='random',
#     verbose=True,
#     random_state=None,
#     method='barnes-hut',
#     angle=0.8,
#     learning_rate_method='adaptive',
#     n_neighbors=90,
#     perplexity_max_iter=100,
#     exaggeration_iter=250,
#     pre_momentum=0.5,
#     post_momentum=0.8,
#     handle=None,
#     output_type='numpy',
# )

dbscan = sklearn.cluster.DBSCAN(
        eps=475,
        min_samples=3, 
        metric='euclidean',
        metric_params=None, 
        algorithm='auto',
        leaf_size=30, 
        p=2, 
        n_jobs=-1
    )

# %% [markdown]
# Main code block: \
# computes matches across sessions for each block

# %%
torch_helpers.delete_all_cuda_tensors(globals())

# %%
import torch
X = torch.as_tensor(sf_block_flat).T

# %%
X = X / torch.sum(X, dim=0, keepdim=True)

# %%
X.shape
# Out:
# torch.Size([524288, 9802])

# %%
Y = similarity.batched_covariance(X, batch_size=3000, device='cuda')
# Out:
# ...
# inner loop:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from rastermap import Rastermap

# %%
rmap = Rastermap(
    n_components=2,
    n_X=40,
    nPC=200,
    init='pca',
    alpha=1.0,
    K=1.0,
    mode='basic',
    verbose=True,
    annealing=True,
    constraints=2,
)

# %%
embedding = rmap.fit_transform(sf_block_flat)
# Out:
# nmin 100
# 32.43195080757141

# %%
embedding.shape
# Out:
# (2000, 2)

# %%
plt.figure()
plt.scatter(embedding[:,0], embedding[:,1])

# %%
Y.max()
# Out:
# tensor(18219., device='cuda:0')

# %%
X.max()
# Out:
# tensor(106.)

# %%
X.max(1)
# Out:
# torch.return_types.max(
# values=tensor([ 5.,  7.,  5.,  ..., 26., 43.,  6.]),
# indices=tensor([432162, 400928, 377220,  ..., 195811, 254189,  15899]))

# %%
X.max(1).values[23423:23429]
# Out:
# tensor([0., 0., 0., 0., 0., 0.])

# %%
plt.figure()
plt.plot(X.sum(0))

# %%
torch.sum(cov.cpu()>2)
# Out:
# tensor(45452)

# %%
cov.max()
# Out:
# tensor(18219., device='cuda:0')

# %%
idx_roi_cat = np.concatenate([np.arange(sfs.shape[0]) for sfs in ROIs_aligned]) # indices of each ROI concatenated together
idx_roi_day = np.concatenate([np.ones(sfs.shape[0])*ii for ii,sfs in enumerate(ROIs_aligned)])

# block_rois = []
# for ii, block in enumerate(tqdm(blocks)):
    ## Make ROI features: flatten ROIs
# #     sf_block_cat = np.concatenate([sfs for sfs in ROIs_aligned], axis=0) # cropped spatial footprints. shape=(n_rois across all sessions, block_height, block_width)
# sf_block_cat = np.concatenate([sfs.toarray().reshape(sfs.shape[0], frame_height, frame_width)for sfs in ROIs_aligned], axis=0) # cropped spatial footprints. shape=(n_rois across all sessions, block_height, block_width)
# #     idx_outOfFrame = np.sum(sf_block_cat, axis=(1,2)) == 0 # roi idx bool that have no pixels in the current block
# #     idx_roi_inFrame = idx_outOfFrame==False # roi idx bool that have any pixels in the current block
# #     sf_block_cat_inFrame =  sf_block_cat[idx_roi_inFrame] # cropped spatial footprints only of rois with any pixels within the block. shape=(n_rois across all sessions within block, block_height, block_width)
# #     sf_block_flat = sf_block_cat_inFrame.reshape(sf_block_cat_inFrame.shape[0], -1) # flattened version of above. flattened rois within block. shape=(n_rois within block, block_height*block_width)
# sf_block_flat = sf_block_cat.reshape(sf_block_cat.shape[0], -1) # flattened version of above. flattened rois within block. shape=(n_rois within block, block_height*block_width)
sf_block_flat = np.concatenate([ROIs_aligned[ii].toarray() for ii in range(len(ROIs_aligned))], axis=0)
# sf_block_flat = np.concatenate([ROIs_aligned[ii].toarray() for ii in range(2)], axis=0)
    
#     idx_roiDay_inFrame = idx_roi_day[idx_outOfFrame==False] # the session/day of each roi that is in frame. shape=(n_rois within block)

# %%
## TSNE
# embeddings = tsne.fit_transform(X=sf_block_flat**0.3)*1000 # scaling at the end is to make it more 'binary mask like' (**0.3), and to increase the separation for the DBSCAN epsilon tuning (*1000)
embeddings = tsne.fit_transform(X=1/(cov.cpu()+(1/100000))) # scaling at the end is to make it more 'binary mask like' (**0.3), and to increase the separation for the DBSCAN epsilon tuning (*1000)
# Out:
# [t-SNE] Computing 601 nearest neighbors...
# [t-SNE] Indexed 9802 samples in 0.159s...
# [t-SNE] Computed neighbors for 9802 samples in 0.660s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9802
# [t-SNE] Computed conditional probabilities for sample 2000 / 9802
# [t-SNE] Computed conditional probabilities for sample 3000 / 9802
# [t-SNE] Computed conditional probabilities for sample 4000 / 9802
# [t-SNE] Computed conditional probabilities for sample 5000 / 9802
# [t-SNE] Computed conditional probabilities for sample 6000 / 9802
# [t-SNE] Computed conditional probabilities for sample 7000 / 9802
# [t-SNE] Computed conditional probabilities for sample 8000 / 9802
# [t-SNE] Computed conditional probabilities for sample 9000 / 9802
# [t-SNE] Computed conditional probabilities for sample 9802 / 9802
# [t-SNE] Mean sigma: 38261.824734
# [t-SNE] Computed conditional probabilities in 5.059s
# ...

# %%
idx_roi_cat = np.concatenate([np.arange(sfs.shape[0]) for sfs in ROIs_aligned]) # indices of each ROI concatenated together
idx_roi_day = np.concatenate([np.ones(sfs.shape[0])*ii for ii,sfs in enumerate(ROIs_aligned)])

block_rois = []
for ii, block in enumerate(tqdm(blocks)):
    ## Make ROI features: flatten ROIs
#     sf_block_cat = np.concatenate([sfs[:,block[0][0]:block[0][1], block[1][0]:block[1][1]] for sfs in ROIs_aligned], axis=0) # cropped spatial footprints. shape=(n_rois across all sessions, block_height, block_width)
    sf_block_cat = np.concatenate([sfs.toarray().reshape(sfs.shape[0], frame_height, frame_width)[:,block[0][0]:block[0][1], block[1][0]:block[1][1]] for sfs in ROIs_aligned], axis=0) # cropped spatial footprints. shape=(n_rois across all sessions, block_height, block_width)
    idx_outOfFrame = np.sum(sf_block_cat, axis=(1,2)) == 0 # roi idx bool that have no pixels in the current block
    idx_roi_inFrame = idx_outOfFrame==False # roi idx bool that have any pixels in the current block
    sf_block_cat_inFrame =  sf_block_cat[idx_roi_inFrame] # cropped spatial footprints only of rois with any pixels within the block. shape=(n_rois across all sessions within block, block_height, block_width)
    sf_block_flat = sf_block_cat_inFrame.reshape(sf_block_cat_inFrame.shape[0], -1) # flattened version of above. flattened rois within block. shape=(n_rois within block, block_height*block_width)
    
    idx_roiDay_inFrame = idx_roi_day[idx_outOfFrame==False] # the session/day of each roi that is in frame. shape=(n_rois within block)
    
    ## TSNE
    embeddings = tsne.fit_transform(X=sf_block_flat**0.3)*1000 # scaling at the end is to make it more 'binary mask like' (**0.3), and to increase the separation for the DBSCAN epsilon tuning (*1000)
    
#     ## DBSCAN
#     db = copy.copy(dbscan)
#     db.fit(embeddings) # note that db.labels_==-1 means no cluster found
    
#     ## Process labels
#     labels_unique = np.unique(db.labels_) 
#     labels_unique = labels_unique[labels_unique > 0] # array of all the non (-1) labels 
    
#     rois_clustered = [sf_block_flat[db.labels_[db.labels_==ii]] for ii in labels_unique] # list of clusters. Each element has the flat spatial footprints for that roi
#     rois_clustered_FOV = [rois.reshape(rois.shape[0], block_height,block_width) for rois in rois_clustered] # list of clusters. Each element has the reshaped spatial footprints for that roi
    
    block_rois.append({
#         "sf_block_cat": sf_block_cat,
        "idx_outOfFrame": idx_outOfFrame,
        "idx_roi_inFrame": idx_roi_inFrame,
#         "sf_block_cat_inFrame": sf_block_cat_inFrame,
#         "sf_block_flat": sf_block_flat,
        "idx_roiDay_inFrame": idx_roiDay_inFrame,
        "embeddings": embeddings,
#         "db": db,
#         "labels_unique": labels_unique,
#         "rois_clustered": rois_clustered,
#         "rois_clustered_FOV": rois_clustered_FOV,
    })
#     if ii >=0:
#         break

# %%
for ii, block_roi in enumerate(tqdm(block_rois)):
    ## DBSCAN
    db = copy.copy(dbscan)
    db.fit(block_roi['embeddings']) # note that db.labels_==-1 means no cluster found
    
    block_roi['db'] = db
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
# pickle_helpers.simple_save(block_rois, '/media/rich/bigSSD/analysis_data/mouse 2_6/multiday_alignment/block_rois.pkl')

# %%
# block_rois = pickle_helpers.simple_load('/media/rich/bigSSD/analysis_data/mouse 2_6/multiday_alignment/block_rois.pkl')

# %%
## Process inner block (ROI idx ownership)
idx_roi_inInnerBlock = []
for ii, block in enumerate(tqdm(inner_blocks)):
    sf_block_cat = np.concatenate([sfs.toarray().reshape(sfs.shape[0], frame_height, frame_width)[:,block[0][0]:block[0][1], block[1][0]:block[1][1]] for sfs in ROIs_aligned], axis=0) # cropped spatial footprints. shape=(n_rois across all sessions, inner_block_height, inner_block_width)
    idx_outOfInnerBlock = np.sum(sf_block_cat, axis=(1,2)) == 0 # roi idx bool that have no pixels in the current block
    idx_roi_inInnerBlock.append(idx_outOfInnerBlock==False) # roi idx bool that have any pixels in the current block
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %% [raw]
# labels_allBlocks = np.ones((len(block_rois), len(block_rois[0]['idx_roi_inFrame']))) * np.nan
# labels_allInnerBlocks = np.ones((len(block_rois), len(block_rois[0]['idx_roi_inFrame']))) * np.nan
# roi_labelFreqs = np.ones((len(block_rois), len(block_rois[0]['idx_roi_inFrame']))) * np.nan
# for i_block, block in enumerate(tqdm(block_rois)):
#     labels_allBlocks[i_block, block['idx_roi_inFrame']] = block['db'].labels_
#     labels_allInnerBlocks[i_block] = labels_allBlocks[i_block] * idx_roi_inInnerBlock[i_block]
#
#     labels_unique = np.unique(block['db'].labels_)
#     label_sizes = [list(block['db'].labels_).count(label) for label in labels_unique]
#     tmp_roi_labelFreqs = [np.array(label_sizes)[labels_unique==label] for label in labels_allInnerBlocks[i_block]]
#     roi_labelFreqs[i_block] = np.concatenate([np.array([np.nan]) if val.shape[0]==0 else val for val in tmp_roi_labelFreqs])

# %% [markdown]
# Heuristic to determine which block to trust for each ROI:
#
# - for each block, determine how many rois are a part of each cluster
# - for each roi, determine how many 'neighbor' rois are in it's cluster
#
#
# - then, for each roi, trust the block that clustered it with the greatest number of ROIs that wasn't too many (ranges between a user defined range)

# %%
roi_labelFreqs = np.ones((len(block_rois), len(block_rois[0]['idx_roi_inFrame']))) * np.nan
for i_block, block in enumerate(tqdm(block_rois)):
    labels = block['db'].labels_
    labels_unique = np.unique(labels)
    label_sizes = [list(labels).count(label) for label in labels_unique]
    for i_roi in range(len(block_rois[0]['idx_roi_inFrame'])):
        idx_outer = np.where(block_rois[i_block]['idx_roi_inFrame'])[0]
        if i_roi in idx_outer: # check if roi was in the outer frame
            arg_outer = np.where(i_roi == idx_outer) # get argument in outer list of this roi
            if i_roi in np.where(idx_roi_inInnerBlock[i_block])[0]: # check if roi was in the inner frame
                label = labels[arg_outer] # get the label of this roi in this block
                arg_unique = np.where(labels_unique == label)[0][0]
                size = label_sizes[arg_unique]
                
                roi_labelFreqs[i_block, i_roi] = size # shape = (n_blocks, n_roi total), values= n_roi in cluster for a given roi in a given block
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]

# %%
# %matplotlib notebook
plt.figure()
# plt.imshow(labels_allInnerBlocks.T, aspect='auto', interpolation='none')
plt.imshow(roi_labelFreqs.T, aspect='auto', interpolation='none', vmax=7)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
roi_labelFreqs_noNaN = copy.copy(roi_labelFreqs)
roi_labelFreqs_noNaN[np.isnan(roi_labelFreqs_noNaN)] = 0
roi_labelFreqs_noNaN = roi_labelFreqs_noNaN.astype(np.int64)

# %%
clusterSizeRange = [7,7]
roi_labelFreqs_ranged = roi_labelFreqs_noNaN * (roi_labelFreqs_noNaN<=clusterSizeRange[1]) * (roi_labelFreqs_noNaN>=clusterSizeRange[0])
roiBestBlock = np.argmax(roi_labelFreqs_ranged, axis=0)
roiBestBlock[roi_labelFreqs_ranged.max(0) == 0] = -1

# %% [markdown]
# now go into the 'best block' for each roi and get it's label

# %%
labels_best = np.ones(len(block_rois[0]['idx_roi_inFrame'])) * -2 + 1j*0
for i_roi, bb in enumerate(tqdm(roiBestBlock)):
    if bb != -1:
        idxAll_in_bb = np.where(block_rois[bb]['idx_roi_inFrame'])[0]
        idx_in_bb = np.where(i_roi == idxAll_in_bb)[0]
        labels_best[i_roi] = block_rois[bb]['db'].labels_[idx_in_bb] + 1j*bb
# Out:
#   0%|          | 0/34217 [00:00<?, ?it/s]

# %%
labels_best_uniques = np.unique(labels_best)
labels_cat_final = np.ones(len(labels_best), dtype=np.int64) * -1
for ii in range(len(labels_best_uniques)):
    labels_cat_final[np.where(labels_best == labels_best_uniques[ii])[0]] = ii

# %%
labels_cat_final[:100]
# Out:
# array([  3,   9,   7,   4,   6,   0,  17,  32,  22,   2,  20,  43,  14,
#          0,  12,  10,   8,   0,  36,  24,   0,  13,   1,  31,  21,  19,
#         33,   0,  46,  44,  35,  56,  16,  57,  37,  47,  27,  53,   5,
#         18,  34,  76,  28,  41,  54,  58,  26,  40,  72,  23,   0,  15,
#         82,  50,  52,  63,  96,  39, 104,  45,  86,  70,  11,  77,  73,
#         30,  25,  66,  61,  55,  62,  75,  83,  69,  79,   0,  64,  87,
#         38,  93,  49,  95,  60, 102,  85,  48,  94,  78,  42,  67,  88,
#         71,  97, 118, 105,  65, 111, 123,   0, 137])

# %%
labels_final = np.array([labels_cat_final[idx_roi_day.astype(np.int64) == ii] for ii in np.unique(idx_roi_day.astype(np.int64))], dtype=object)

# %%
# np.save(
#     file='/media/rich/bigSSD/analysis_data/mouse 2_6/multiday_alignment/labels.npy',
#     arr=labels_final
# )

# %%
# test = np.load('/media/rich/bigSSD/analysis_data/mouse 2_6/multiday_alignment/labels.npy', allow_pickle=True)

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
sc = ax.scatter(embeddings[:,0], embeddings[:,1])

def update(eps = 1.0):
    eps_toUse = (eps/10)**2
    # Compute DBSCAN
    db = sklearn.cluster.DBSCAN(
        eps=eps_toUse,
        min_samples=2, 
        metric='euclidean',
        metric_params=None, 
        algorithm='auto',
        leaf_size=30, 
        p=2, 
        n_jobs=-1
    ).fit(embeddings)

    cmap = plotting_helpers.rand_cmap(db.labels_.max(), verbose=False)

    sc.set_color(cmap(db.labels_))

    fig.canvas.draw_idle()
    ax.set_title(f'eps={round(eps_toUse,1)}, n_clusters={db.labels_.max()}')

interact(update, eps=widgets.IntSlider(min=0, max=30, step=1, value=100));
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# interactive(children=(IntSlider(value=30, description='eps', max=30), Output()), _dom_classes=('widget-interac…
