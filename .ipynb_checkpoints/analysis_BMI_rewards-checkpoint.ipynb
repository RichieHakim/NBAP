# %%
# widen jupyter notebook window
from IPython.display import display, HTML
display(HTML("<style>.container {width:95% !important; }</style>"))

# check environment
import os
print(f'Conda Environment: ' + os.environ['CONDA_DEFAULT_ENV'])

from platform import python_version
print(f'python version: {python_version()}')
# Out:
# <style>.container {width:95% !important; }</style>
# Conda Environment: FR
# python version: 3.9.13

# %%
import pprint
from pathlib import Path

import natsort
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# %load_ext autoreload
# %autoreload 2
import bnpm

# %% [markdown]
# # Get logger file from server

# %% [markdown]
# input credentials for server

# %%
import getpass

remote_host_transfer = "transfer.rc.hms.harvard.edu"
remote_host_compute = "o2.hms.harvard.edu"
username = input('Username: ')
pw = bnpm.server.pw_encode(getpass.getpass(prompt='Password: '))
# Out:
# Username: rh183
# Password: ········

# %% [markdown]
# prepare sftp client

# %%
ssh_t = bnpm.server.ssh_interface()

ssh_t.o2_connect(
    hostname=remote_host_transfer,
    username=username,
    password=bnpm.server.pw_decode(pw),
    skip_passcode=False,
    key_filename=None,
    look_for_keys=False,
    passcode_method=1,
    verbose=1,
)

sftp_t = bnpm.server.sftp_interface(ssh_t.client)
# Out:
# Duo two-factor login for rh183
#
# Enter a passcode or select one of the following options:
#
#  1. Duo Push to XXX-XXX-4151
#  2. Phone call to XXX-XXX-4151
#  3. SMS passcodes to XXX-XXX-4151
#
# Passcode or option (1-3):
# 1
#
#
#
# Pushed a login request to your device...
#
# Please open Duo Mobile and check for Duo Push requests manually.
#
# Success. Logging you in...
# Welcome to O2 (Orchestra 2)!
#
#    ___    ____
#   / _ \  |___ \
#  | | | |   __) |
#  | |_| |  / __/
#   \___/  |_____|
#
#
# You've landed on transfer05 which is a
# 4 core system with 7.62 GiB memory
# running kernel 3.10.0 born on 2020-07-28
#
# ==== O2 ===================================================================
#
#   News (Sep 8 2022)
#
#
#   +-------------------------------------------------------------------------------+
#   | ###################### Try out the new O2 Portal! ########################### |
#   |                                                                               |
#   | * Access O2 via the web! Just point your web browser to                       |
#   |   o2portal.rc.hms.harvard.edu and login with your O2 credentials.             |
#   |                                                                               |
#   | * Graphical interface for file browsing, editing, and transfer                |
#   |   (with only 1 DUO 2-factor check per session)                                |
#   |                                                                               |
#   | * Better support for graphical applications, with no x11 forwarding needed.   |
#   |   includes: MATLAB, RStudio, Jupyter, and IGV                                 |
#   |                                                                               |
#   | * Open multiple O2 terminals or even a full Linux desktop in your browser.    |
#   |                                                                               |
#   | * More info on the O2 wiki:                                                   |
#   |   https://harvardmed.atlassian.net/wiki/spaces/O2/pages/2230583317/O2Portal   |
#   +-------------------------------------------------------------------------------+
#
#   ------------------------------
#   Contact HMS Research Computing:
#
#   E-mail      rchelp@hms.harvard.edu
#   Web         it.hms.harvard.edu/rc
#   Twitter     @hms_rc
#
# ===========================================================================
#
#
#
# (base) [rh183@transfer05 ~]$

# %% [markdown]
# ### find files
# Search for logger files and associated expParams files

# %%
# paths_logger = sftp_t.search_recursive(
#     path=r'/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6',
#     search_pattern_re='logger.mat',
#     max_depth=12,
#     find_files=True,
#     find_folders=False,
#     verbose=True,
# )

# paths_logger = natsort.natsorted(paths_logger)
# display(paths_logger)
# Out:
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210412/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210417/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210414/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210411/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210415/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210416/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210410/analysis_lastNight/simulation/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210410/logger.mat
# /n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210413/logger.mat
# ['/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210410/analysis_lastNight/simulation/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210410/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210411/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210412/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210413/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210414/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210415/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210416/logger.mat',
#  '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210417/logger.mat']

# %% [markdown]
# ### WARNING:
#
# This script/notebook is meant to run on data collected starting with `round 5 experiments` as that is the first time I started using 'trials'

# %% [markdown]
# mouse 2_6

# %%
paths_logger = [
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210410/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210411/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210412/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210413/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210414/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210415/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210416/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Rich/data/res2p/old_data/scanimage data/round 5 experiments/mouse 2_6/20210417/logger.mat',
]

# %% [markdown]
# mouse B

# %%
paths_logger = [
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221020/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221021/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221022/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221023/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221024/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221025/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221026/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221027/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221028/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221029/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221030/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221031/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221101/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221102/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221103/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221104/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221105/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_B/20221106/analysis_data/logger.mat',
]

# %% [markdown]
# mouse g1

# %%
paths_logger = [
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_g1/20221010/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_g1/20221011/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_g1/20221013/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_g1/20221014/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_g1/20221015/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/mouse_g1/20221016/analysis_data/logger.mat',
]

# %% [markdown]
# mouse g2FB

# %%
paths_logger = [
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221111/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221112/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221113/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221114/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221115/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221116/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221117/analysis_data/logger.mat',
    '/n/files/Neurobio/MICROSCOPE/Gyu/BMI_data/BMI_cage_g2F/mouse_g2FB/20221118/analysis_data/logger.mat',
]

# %%
dirs_logger = [str(Path(p).resolve().parent) for p in paths_logger]

paths_expParams = [str(Path(d).resolve() / 'expParams.mat') for d in dirs_logger]
# paths_loggerAlignmentVectors = [str(Path(d).resolve() / 'logger_alignment_vectors.mat') for d in dirs_logger]
# paths_loggerAligned = [str(Path(d).resolve() / 'logger_aligned.mat') for d in dirs_logger]

assert all([sftp_t.exists(p) for p in paths_expParams])
# assert all([sftp_t.exists(p) for p in paths_loggerAlignmentVectors])
# assert all([sftp_t.exists(p) for p in paths_loggerAligned])

# %% [markdown]
# ### get logger and expParams files
# Pull them into a temp directory structure

# %% [markdown]
# make a directory structure based on the naming of the directories in remote.\
# Might need to add or remove `.parent` suffices to `Path(p).resolve().parent`

# %%
dir_save_outer = r'/media/rich/bigSSD/downloads_tmp/loggers'
folderNames_session = [str(Path(p).resolve().parent.parent.name) for p in paths_logger]
dirs_save_session = [str(Path(dir_save_outer).resolve() / n) for n in folderNames_session]

# %% [markdown]
# check to make sure these are the dated session folder names

# %%
display(folderNames_session)
# Out:
# ['20221020',
#  '20221021',
#  '20221022',
#  '20221023',
#  '20221024',
#  '20221025',
#  '20221026',
#  '20221027',
#  '20221028',
#  '20221029',
#  '20221030',
#  '20221031',
#  '20221101',
#  '20221102',
#  '20221103',
#  '20221104',
#  '20221105',
#  '20221106']

# %%
## Make directories
[Path(d).mkdir(parents=True, exist_ok=True) for d in dirs_save_session];

## Enumerate paths for each session
paths_transfer = {folderName: {
    'path_logger_remote': paths_logger[i_folder], 
    'path_logger_local': str(Path(dirs_save_session[i_folder]) / 'logger.mat'),
    'path_expParams_remote': paths_expParams[i_folder],
    'path_expParams_local': str(Path(dirs_save_session[i_folder]) / 'expParams.mat'),
#     'path_loggerAlignmentVectors_remote': paths_loggerAlignmentVectors[i_folder],
#     'path_loggerAlignmentVectors_local': str(Path(dirs_save_session[i_folder]) / 'logger_alignment_vectors.mat'),
#     'path_loggerAligned_remote': paths_loggerAligned[i_folder],
#     'path_loggerAligned_local': str(Path(dirs_save_session[i_folder]) / 'logger_aligned.mat'),
} for i_folder, folderName in enumerate(folderNames_session)}

# %%
for folderName, paths in tqdm(paths_transfer.items()):
    sftp_t.sftp.get(remotepath=paths['path_logger_remote'], localpath=paths['path_logger_local'])
    sftp_t.sftp.get(remotepath=paths['path_expParams_remote'], localpath=paths['path_expParams_local'])
#     sftp_t.sftp.get(remotepath=paths['path_loggerAlignmentVectors_remote'], localpath=paths['path_loggerAlignmentVectors_local'])
#     sftp_t.sftp.get(remotepath=paths['path_loggerAligned_remote'], localpath=paths['path_loggerAligned_local'])
# Out:
# 100%|███████████████████████████████████████████| 18/18 [00:10<00:00,  1.76it/s]

# %% [markdown]
# # Import logger and expParams

# %%
import scipy.io
import pandas as pd
import numpy as np
import matplotlib as mpl

# %% [markdown]
# make lists of logger dicts and expParams dicts

# %%
logger_objs    = [scipy.io.loadmat(file_name=p, simplify_cells=True)['logger']    for p in [pt['path_logger_local']    for folderName,pt in paths_transfer.items()]]
expParams_objs = [scipy.io.loadmat(file_name=p, simplify_cells=True)['expParams'] for p in [pt['path_expParams_local'] for folderName,pt in paths_transfer.items()]]
# loggerAlignmentVectors_objs = [scipy.io.loadmat(file_name=p, simplify_cells=True)['logger_alignment_vectors'] for p in [pt['path_loggerAlignmentVectors_local'] for folderName,pt in paths_transfer.items()]]
# loggerAligned_objs = [scipy.io.loadmat(file_name=p, simplify_cells=True)['logger_aligned'] for p in [pt['path_loggerAligned_local'] for folderName,pt in paths_transfer.items()]]

# %% [markdown]
# make dataframes for each logger using the loggerNames field from expParams

# %% [markdown]
# ### WARNING:
#
# in the line:
# ```
# ...
#             data=logger[key_outer][:, :len(expParams['loggerNames'][key_outer])],
# ...
# ```
# the indexing: `[:, :len(expParams['loggerNames'][key_outer])]` is used because the length of the logger is sometimes too long. This should be fine for most experiments, but just a heads up that if the `expParams['loggerNames']` and actual logger data doesn't match up then this is screwed.

# %%
logger_dfs = {
    folderName: {
        key_outer: pd.DataFrame(
            data=logger[key_outer][:, :len(expParams['loggerNames'][key_outer])], 
            columns=expParams['loggerNames'][key_outer],
        ) for key_outer in expParams['loggerNames'].keys()
    } for (folderName, logger, expParams) in zip(folderNames_session, logger_objs, expParams_objs)
}

# %%
# loggerAligned_dfs = {
#     folderName: {
#         key_outer: pd.DataFrame(
#             data=logger[key_outer], 
#             columns=expParams['loggerNames'][key_outer]
#         ) for key_outer in logger.keys()
#     } for (folderName, logger, expParams) in zip(folderNames_session, loggerAligned_objs, expParams_objs)
# }

# %%
# bnpm.h5_handling.show_item_tree(logger_dfs)

# %% [markdown]
# Determine the duration of each trial.\
# Note that the `'trial_now_'` fields appear to be busted. So it is safter to use the `'counter_frameNum_'` fields and just make sure to correct them using the alignment vectors.

# %% [markdown]
# To align raw logger indices to scanimage/suite2p indices, use the `logger_alignment_vectors` file and the `inds_align_movie_to_logger` field within it. You can use the `bnpm.indexing.index_with_nans` function to reindex a raw logger time series as such:
# ```
# ts_SI = bnpm.indexing.index_with_nans(
#     values=ts_logger,
#     indices=logger_alignment_vectors['inds_align_movie_to_logger']-1
# )
# ```
#
# To convert index values from logger indices to scanimage/suite2p indices, use the `inds_align_logger2movie` field. You can also use it with the `index_with_nans` function as such:
# ```
# frame_start_SI = bnpm.indexing.index_with_nans(
#         values=logger_alignment_vectors['inds_align_logger2movie'],
#         indices=frame_start_logger,
#     )

# %% [markdown]
# Also note that loggers BEFORE 2022.12.13 have a bug that appears in failure trials that occur after failure trials. Their duration will appear negative. This is because the update trial info happens after iterating the trial number instead of before:
# ```
# trialNum = trialNum + 1
# updateLoggerTrials_END(0)
# ```

# %% [markdown]
# ### Extract trial statistics

# %%
Fs = 30

n_sessions = len(logger_dfs)

trials_duration_frame = []
trials_duration_nowTime = []
trials_success = []
trials_type_111 = []

for logger_df in logger_dfs.values():
    ## pull out frames of start and end. -1 to account for matlab 1-indexing
    frame_start__idx_logger = logger_df['trials']['counter_frameNum_trialStart'].to_numpy() - 1
    frame_end__idx_logger = logger_df['trials']['counter_frameNum_trialEnd'].to_numpy() - 1   
#     frame_start__idx_SI = bnpm.indexing.index_with_nans(
#         values=align['inds_align_logger2movie'],
#         indices=frame_start__idx_logger,
#     )
#     frame_end__idx_SI = bnpm.indexing.index_with_nans(
#         values=align['inds_align_logger2movie'],
#         indices=frame_end__idx_logger,
#     )
#     trials_duration_frame.append((frame_end__idx_SI - frame_start__idx_SI))
    
    ## pull out durations using time
    time_start__idx_logger = logger_df['trials']['time_now_trialStart'].to_numpy()
    time_end__idx_logger = logger_df['trials']['time_now_trialEnd'].to_numpy()
    trials_duration_nowTime.append((time_end__idx_logger - time_start__idx_logger))

    ## pull out whether the outcome was a success
    trials_success.append(logger_df['trials']['success_outcome'] == 1)
    
    ## pull out whether the trial type was a standard trial with feedback, reward, and cursor all one (1 1 1)
    trials_type_111.append((logger_df['trials']['trialType_cursorOn'] == 1) * (logger_df['trials']['trialType_feedbackLinked'] == 1) * (logger_df['trials']['trialType_rewardOn'] == 1))

# %% [markdown]
# Plot number of successful trials over sessions

# %%
trials_numSuccess__111 = [np.nansum(trials_success[ii][trials_type_111[ii]]) for ii in range(n_sessions)]

# %%
plt.figure()
plt.plot(trials_numSuccess__111)
plt.xlabel('session number')
plt.ylabel('number of rewards');

# %% [markdown]
# Plot duration of successful trials over sessions as a histogram

# %%
trials_duration_time__success_111 = [trials_duration_nowTime[sn][trials_success[sn] * trials_type_111[sn]] * 24*60*60 for sn in range(len(trials_duration_nowTime))]

edges = np.linspace(0,20, num=41, endpoint=True)
trials_durationHist_time__success_111 = np.array([np.histogram(t, bins=edges)[0] for t in trials_duration_time__success_111]).T

# %%
cmap = bnpm.plotting_helpers.simple_cmap(colors=[[0.0, 0.0, 1.0], [0.0, 0.75, 0.75], [0.0, 0.7, 0.0], [0.75, 0.75, 0], [0.85, 0.0, 0.0]])

plt.figure()
for ii,trace in enumerate(trials_durationHist_time__success_111.T):
    plt.plot(
        (edges[1:] +edges[:-1])/2, 
        trace, 
        color=cmap(ii/(n_sessions-1)), 
        linewidth=4,
        alpha=0.6,
    )
    
# [plt.stairs(t[0], t[1], color=colors[ii], linewidth=4) for ii,t in enumerate(trials_durationHist_time__success_111)];
plt.xlabel('duration trial (s) [successes]')
plt.ylabel('counts')
plt.legend([f'session_{ii}' for ii in np.arange(n_sessions)+1])
ax = plt.gca()
plt.colorbar(mpl.cm.ScalarMappable(cmap=cmap), ax=ax);

# %%
plt.figure()
plt.plot(trials_durationHist_time__success_111[:5,:].sum(0))
plt.xlabel('session number')
plt.ylabel('successes (within 2.5 sec)')
# Out:
# Text(0, 0.5, 'successes (within 2.5 sec)')

# %% [markdown]
# ### NOTE:
#
# In earlier experiments use `CE_ITI_successful` and in later experiments use `CE_ITI_withZ`

# %%
fig, axs = plt.subplots(n_sessions, 1, sharex=True, figsize=(50, n_sessions*1.5))

for i_sesh in range(n_sessions):

    names_states = expParams_objs[i_sesh]['loggerNames']['timeSeries']

    names_toPlot = [
        'CE_trial',
        'CE_rewardToneHold',
        'CE_rewardDelivery',
        'CE_ITI_withZ',
        'CE_waitForBaseline',
        'CE_timeout'
    ]
    idx_toPlot = np.isin(names_states, names_toPlot)

    n_samples = logger_objs[i_sesh]['timeSeries'].shape[0]

    colors = {
        'CE_trial': (0.7, 0.7, 0.7),
        'CE_rewardToneHold': (0.0, 0.7, 0.0),
        'CE_rewardDelivery': (0.0, 0.7, 0.2),
        'CE_ITI_withZ': (0.0, 0.7, 0.6),
        'CE_waitForBaseline': (0.2, 0.2, 0.1),
        'CE_timeout': (1.0, 0.2, 0.0),
    }

    assert all([n_c == n_tp for n_c, n_tp in zip(list(colors.keys()), names_toPlot)])

    for name in names_toPlot:
        axs[i_sesh].fill_between(
            x=np.arange(n_samples),
            y1=logger_objs[i_sesh]['timeSeries'][:, np.isin(names_states, name)][:,0] * 10 - 5,
            y2=-5,
            alpha=0.6,
            color=colors[name],
            linewidth=0
        )
    axs[i_sesh].plot(logger_objs[i_sesh]['decoder'][:, expParams_objs[0]['loggerNames']['decoder'] == 'cursor_brain'], 'k')
    axs[i_sesh].set_ylim(-2,3)

# %% [markdown]
# ### Save results
#
# Make a nice little dictionary with all the relevant information

# %%
name_animal = 'mouse_2_6'

# %%
data_output = {
    'name_animal': name_animal,
    'paths_logger': paths_logger,
    'paths_expParams': paths_expParams,
    'dirs_logger': dirs_logger,
    'paths_transfer': paths_transfer,
#     'logger_objs': logger_objs,
#     'expParams_objs': expParams_objs,
#     'logger_dfs': logger_dfs,
    'n_sessions': n_sessions,
    'trials_duration_nowTime': trials_duration_nowTime,
    'trials_success': trials_success,
    'trials_type_111': trials_type_111,
    'trials_numSuccess__111': trials_numSuccess__111,
    'trials_duration_time__success_111': trials_duration_time__success_111,
    'edges': edges,
    'trials_durationHist_time__success_111': trials_durationHist_time__success_111,
    'names_states': names_states,
}

# %% [markdown]
# save the analysis outputs and the logger and expParams objects

# %%
bnpm.file_helpers.pickle_save(
    obj=data_output,
    path_save=str(Path(r'/media/rich/bigSSD/analysis_data/BMI/analysis_BMI_rewards').resolve() / name_animal / (name_animal + '__analysis_BMI_rewards' + '.pkl')),
    mkdir=True,
)

bnpm.file_helpers.pickle_save(
    obj={
        'logger_dfs': logger_dfs,
        'logger_objs': logger_objs,
        'expParams_objs': expParams_objs,
    },
    path_save=str(Path(r'/media/rich/bigSSD/analysis_data/BMI/analysis_BMI_rewards').resolve() / name_animal / (name_animal + '__logger_expParams' + '.pkl')),
    mkdir=True
)

# %%
import cv2

vc = cv2.VideoCapture('/mnt/MICROSCOPE/Rich/data/res2p/experiments_round_6/mouse_1_19/camera_data/20220316/cam3/baseline/cam32022-03-16T19_03_41.avi')

s, im = vc.read()

# %%
import distutils

# %%
import distutils.core

# %%
distutils.core.run_setup(script_name=r'/media/rich/Home_Linux_partition/github_repos/ROICaT/setup.py')
# Out:
# Installing with environment variables: {'INSTALL_ROICAT_GPU': None}
#
#
# To change, on Windows use: set 'ENVIRONMENT_VARIABLE_NAME=ENVIRONMENT_VARIABLE_VALUE'.
#  On Linux use: ENVIRONMENT_VARIABLE_NAME=ENVIRONMENT_VARIABLE_VALUE.
#
# sys.argv: ['/media/rich/Home_Linux_partition/github_repos/ROICaT/setup.py', '-f', '/home/rich/.local/share/jupyter/runtime/kernel-1439aa90-8c74-44c3-99f1-06573a62aa79.json']
# use_gpu: False, installing requirements from: /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Collecting umap-learn==0.5.3
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# Collecting hdbscan==0.8.28
#   Using cached hdbscan-0.8.28-cp39-cp39-linux_x86_64.whl
# Requirement already satisfied: torch==1.12.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 3)) (1.12.1+cpu)
# Requirement already satisfied: torchvision==0.13.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (0.13.1+cpu)
# Requirement already satisfied: torchaudio==0.12.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 5)) (0.12.1+cpu)
# Collecting gdown==4.5.1
#   Using cached gdown-4.5.1-py3-none-any.whl
# Collecting ipywidgets==7.7.1
#   Using cached ipywidgets-7.7.1-py2.py3-none-any.whl (123 kB)
# Collecting kymatio==0.2.1
#   Using cached kymatio-0.2.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: matplotlib==3.5.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (3.5.2)
# Requirement already satisfied: numpy==1.23.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 11)) (1.23.2)
# Requirement already satisfied: opencv_contrib_python==4.6.0.66 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 12)) (4.6.0.66)
# Requirement already satisfied: pandas==1.4.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 13)) (1.4.3)
# Requirement already satisfied: Pillow==9.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 14)) (9.2.0)
# Requirement already satisfied: scikit_learn==1.1.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 15)) (1.1.2)
# Requirement already satisfied: scipy==1.8.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 16)) (1.8.1)
# Collecting seaborn==0.11.2
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: sparse==0.13.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 18)) (0.13.0)
# Requirement already satisfied: tqdm==4.64.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 19)) (4.64.0)
# Requirement already satisfied: natsort==8.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 20)) (8.2.0)
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: paramiko==2.12.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (2.12.0)
# Requirement already satisfied: pyyaml==5.4.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 23)) (5.4.1)
# Requirement already satisfied: hdfdict==0.3.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (0.3.1)
# Collecting optuna==3.0.1
#   Using cached optuna-3.0.1-py3-none-any.whl (348 kB)
# Requirement already satisfied: joblib==1.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 26)) (1.1.0)
# Requirement already satisfied: Cython==0.29.32 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 27)) (0.29.32)
# Requirement already satisfied: einops==0.6.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 28)) (0.6.0)
# Requirement already satisfied: xxhash==3.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 29)) (3.1.0)
# Requirement already satisfied: pytest==7.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (7.2.0)
# Requirement already satisfied: tox in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (3.27.1)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.8-py3-none-any.whl
# Requirement already satisfied: numba>=0.49 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (0.56.4)
# Requirement already satisfied: typing-extensions in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from torch==1.12.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 3)) (4.4.0)
# Requirement already satisfied: requests in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (4.11.1)
# Requirement already satisfied: filelock in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (3.8.0)
# Requirement already satisfied: six in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (1.16.0)
# Requirement already satisfied: ipython>=4.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (8.6.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.1.1)
# Requirement already satisfied: traitlets>=4.3.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (5.5.0)
# Requirement already satisfied: appdirs in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from kymatio==0.2.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (1.4.4)
# Requirement already satisfied: packaging in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from kymatio==0.2.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (20.9)
# Requirement already satisfied: configparser in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from kymatio==0.2.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (5.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (4.38.0)
# Requirement already satisfied: pytz>=2020.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pandas==1.4.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 13)) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from scikit_learn==1.1.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 15)) (3.1.0)
# Requirement already satisfied: pynacl>=1.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (1.5.0)
# Requirement already satisfied: cryptography>=2.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (38.0.3)
# Requirement already satisfied: bcrypt>=3.1.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (4.0.1)
# Requirement already satisfied: h5py-wrapper<2.0,>=1.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (1.1.0)
# Collecting cliff
#   Using cached cliff-4.1.0-py3-none-any.whl (81 kB)
# Collecting alembic
#   Using cached alembic-1.9.0-py3-none-any.whl (210 kB)
# Requirement already satisfied: cmaes>=0.8.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (0.9.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.4.45)
# Requirement already satisfied: colorlog in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (6.7.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (22.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (2.0.1)
# Requirement already satisfied: iniconfig in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (1.1.1)
# Collecting jupyter-console
#   Using cached jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: nbconvert in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (7.2.5)
# Requirement already satisfied: notebook in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (6.5.2)
# Collecting qtconsole
#   Using cached qtconsole-5.4.0-py3-none-any.whl (121 kB)
# Requirement already satisfied: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (20.17.1)
# Requirement already satisfied: py>=1.4.17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (1.11.0)
# Requirement already satisfied: cffi>=1.12 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cryptography>=2.5->paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (1.15.1)
# Requirement already satisfied: future in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from h5py-wrapper<2.0,>=1.1->hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (0.18.2)
# Requirement already satisfied: pytest-runner in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from h5py-wrapper<2.0,>=1.1->hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (6.0.0)
# Requirement already satisfied: h5py in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from h5py-wrapper<2.0,>=1.1->hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (3.7.0)
# Requirement already satisfied: psutil in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (5.9.4)
# Requirement already satisfied: debugpy>=1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.6.3)
# Requirement already satisfied: tornado>=6.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (6.2)
# Requirement already satisfied: pyzmq>=17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (24.0.1)
# Requirement already satisfied: nest-asyncio in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (7.4.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.1.6)
# Requirement already satisfied: pickleshare in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.7.5)
# Requirement already satisfied: backcall in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (3.0.32)
# Requirement already satisfied: decorator in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (2.13.0)
# Requirement already satisfied: pexpect>4.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (4.8.0)
# Requirement already satisfied: stack-data in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.6.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from numba>=0.49->umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (0.39.1)
# Requirement already satisfied: setuptools in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from numba>=0.49->umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (59.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from sqlalchemy>=1.1.0->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (2.0.1)
# Requirement already satisfied: distlib<1,>=0.3.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (0.3.6)
# Requirement already satisfied: platformdirs<3,>=2.4 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (2.5.4)
# Requirement already satisfied: jinja2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.4.8)
# Requirement already satisfied: terminado>=0.8.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.17.0)
# Requirement already satisfied: nbformat in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.7.0)
# Requirement already satisfied: prometheus-client in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.15.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.0.0)
# Requirement already satisfied: argon2-cffi in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (21.3.0)
# Requirement already satisfied: jupyterlab-pygments in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.0.4)
# Requirement already satisfied: bleach in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.0.1)
# Requirement already satisfied: markupsafe>=2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.7.0)
# Requirement already satisfied: defusedxml in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.7.1)
# Requirement already satisfied: tinycss2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.5.0)
# Requirement already satisfied: Mako in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from alembic->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.2.4)
# Requirement already satisfied: soupsieve>1.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from beautifulsoup4->gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (2.3.2.post1)
# Requirement already satisfied: stevedore>=2.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (4.1.1)
# Requirement already satisfied: cmd2>=1.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (2.4.2)
# Requirement already satisfied: autopage>=0.4.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (3.5.0)
# Requirement already satisfied: qtpy>=2.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from qtconsole->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (1.7.1)
# Requirement already satisfied: pycparser in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (2.21)
# Requirement already satisfied: pyperclip>=1.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (3.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.8.3)
# Requirement already satisfied: entrypoints in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.23.2)
# Requirement already satisfied: fastjsonschema in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbformat->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbformat->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (4.17.0)
# Requirement already satisfied: ptyprocess>=0.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.7.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stevedore>=2.0.1->cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (5.11.0)
# Requirement already satisfied: argon2-cffi-bindings in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (21.2.0)
# Requirement already satisfied: webencodings in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.5.1)
# Requirement already satisfied: asttokens>=2.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (2.1.0)
# Requirement already satisfied: pure-eval in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.19.2)
# Requirement already satisfied: websocket-client in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.4.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (3.6.2)
# Requirement already satisfied: sniffio>=1.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.3.0)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# Installing collected packages: kymatio, cliff, alembic, seaborn, pynndescent, optuna, hdbscan, gdown, umap-learn, qtconsole, jupyter-console, ipywidgets, jupyter
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.2
#     Uninstalling ipywidgets-7.7.2:
#       Successfully uninstalled ipywidgets-7.7.2
# Successfully installed alembic-1.9.0 cliff-4.1.0 gdown-4.5.1 hdbscan-0.8.28 ipywidgets-7.7.1 jupyter-1.0.0 jupyter-console-6.4.4 kymatio-0.2.1 optuna-3.0.1 pynndescent-0.5.8 qtconsole-5.4.0 seaborn-0.11.2 umap-learn-0.5.3
#     WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)

# %%
distutils.core.run_setup(script_name=r'/media/rich/Home_Linux_partition/github_repos/ROICaT/setup.py', )
# Out:
# Installing with environment variables: {'INSTALL_ROICAT_GPU': None}
#
#
# To change, on Windows use: set 'ENVIRONMENT_VARIABLE_NAME=ENVIRONMENT_VARIABLE_VALUE'.
#  On Linux use: ENVIRONMENT_VARIABLE_NAME=ENVIRONMENT_VARIABLE_VALUE.
#
# sys.argv: ['/media/rich/Home_Linux_partition/github_repos/ROICaT/setup.py', '-f', '/home/rich/.local/share/jupyter/runtime/kernel-1439aa90-8c74-44c3-99f1-06573a62aa79.json']
# use_gpu: False, installing requirements from: /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Requirement already satisfied: umap-learn==0.5.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (0.5.3)
# Requirement already satisfied: hdbscan==0.8.28 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 2)) (0.8.28)
# Requirement already satisfied: torch==1.12.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 3)) (1.12.1+cpu)
# Requirement already satisfied: torchvision==0.13.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (0.13.1+cpu)
# Requirement already satisfied: torchaudio==0.12.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 5)) (0.12.1+cpu)
# Requirement already satisfied: gdown==4.5.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (4.5.1)
# Requirement already satisfied: ipywidgets==7.7.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (7.7.1)
# Requirement already satisfied: kymatio==0.2.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (0.2.1)
# Requirement already satisfied: matplotlib==3.5.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (3.5.2)
# Requirement already satisfied: numpy==1.23.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 11)) (1.23.2)
# Requirement already satisfied: opencv_contrib_python==4.6.0.66 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 12)) (4.6.0.66)
# Requirement already satisfied: pandas==1.4.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 13)) (1.4.3)
# Requirement already satisfied: Pillow==9.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 14)) (9.2.0)
# Requirement already satisfied: scikit_learn==1.1.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 15)) (1.1.2)
# Requirement already satisfied: scipy==1.8.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 16)) (1.8.1)
# Requirement already satisfied: seaborn==0.11.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 17)) (0.11.2)
# Requirement already satisfied: sparse==0.13.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 18)) (0.13.0)
# Requirement already satisfied: tqdm==4.64.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 19)) (4.64.0)
# Requirement already satisfied: natsort==8.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 20)) (8.2.0)
# Requirement already satisfied: jupyter in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.0.0)
# Requirement already satisfied: paramiko==2.12.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (2.12.0)
# Requirement already satisfied: pyyaml==5.4.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 23)) (5.4.1)
# Requirement already satisfied: hdfdict==0.3.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (0.3.1)
# Requirement already satisfied: optuna==3.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (3.0.1)
# Requirement already satisfied: joblib==1.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 26)) (1.1.0)
# Requirement already satisfied: Cython==0.29.32 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 27)) (0.29.32)
# Requirement already satisfied: einops==0.6.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 28)) (0.6.0)
# Requirement already satisfied: xxhash==3.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 29)) (3.1.0)
# Requirement already satisfied: pytest==7.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (7.2.0)
# Requirement already satisfied: tox in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from -r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (3.27.1)
# Requirement already satisfied: pynndescent>=0.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (0.5.8)
# Requirement already satisfied: numba>=0.49 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (0.56.4)
# Requirement already satisfied: typing-extensions in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from torch==1.12.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 3)) (4.4.0)
# Requirement already satisfied: requests in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (2.27.1)
# Requirement already satisfied: six in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (4.11.1)
# Requirement already satisfied: filelock in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (3.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (6.17.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.1.1)
# Requirement already satisfied: traitlets>=4.3.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (5.5.0)
# Requirement already satisfied: ipython>=4.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (8.6.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.2.0)
# Requirement already satisfied: configparser in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from kymatio==0.2.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (5.3.0)
# Requirement already satisfied: appdirs in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from kymatio==0.2.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (1.4.4)
# Requirement already satisfied: packaging in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from kymatio==0.2.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 9)) (20.9)
# Requirement already satisfied: pyparsing>=2.2.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from matplotlib==3.5.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 10)) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pandas==1.4.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 13)) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from scikit_learn==1.1.2->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 15)) (3.1.0)
# Requirement already satisfied: pynacl>=1.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (4.0.1)
# Requirement already satisfied: cryptography>=2.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (38.0.3)
# Requirement already satisfied: h5py-wrapper<2.0,>=1.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (1.1.0)
# Requirement already satisfied: colorlog in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.4.45)
# Requirement already satisfied: cmaes>=0.8.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (0.9.0)
# Requirement already satisfied: cliff in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (4.1.0)
# Requirement already satisfied: alembic in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.9.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (1.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (2.0.1)
# Requirement already satisfied: iniconfig in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (22.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pytest==7.2.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 30)) (1.0.4)
# Requirement already satisfied: jupyter-console in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (6.4.4)
# Requirement already satisfied: notebook in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (6.5.2)
# Requirement already satisfied: nbconvert in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (7.2.5)
# Requirement already satisfied: qtconsole in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.4.0)
# Requirement already satisfied: py>=1.4.17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (1.11.0)
# Requirement already satisfied: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (20.17.1)
# Requirement already satisfied: cffi>=1.12 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cryptography>=2.5->paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (1.15.1)
# Requirement already satisfied: future in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from h5py-wrapper<2.0,>=1.1->hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (0.18.2)
# Requirement already satisfied: h5py in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from h5py-wrapper<2.0,>=1.1->hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (3.7.0)
# Requirement already satisfied: pytest-runner in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from h5py-wrapper<2.0,>=1.1->hdfdict==0.3.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 24)) (6.0.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (7.4.7)
# Requirement already satisfied: pyzmq>=17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (24.0.1)
# Requirement already satisfied: nest-asyncio in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.5.6)
# Requirement already satisfied: debugpy>=1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.6.3)
# Requirement already satisfied: tornado>=6.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (6.2)
# Requirement already satisfied: psutil in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (5.9.4)
# Requirement already satisfied: backcall in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.2.0)
# Requirement already satisfied: stack-data in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.6.1)
# Requirement already satisfied: pexpect>4.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (4.8.0)
# Requirement already satisfied: decorator in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (3.0.32)
# Requirement already satisfied: pickleshare in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.18.1)
# Requirement already satisfied: setuptools in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from numba>=0.49->umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (59.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from numba>=0.49->umap-learn==0.5.3->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 1)) (0.39.1)
# Requirement already satisfied: greenlet!=0.4.17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from sqlalchemy>=1.1.0->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (2.0.1)
# Requirement already satisfied: platformdirs<3,>=2.4 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (2.5.4)
# Requirement already satisfied: distlib<1,>=0.3.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 31)) (0.3.6)
# Requirement already satisfied: terminado>=0.8.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.17.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.0.0)
# Requirement already satisfied: nbformat in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.7.0)
# Requirement already satisfied: prometheus-client in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.15.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.4.8)
# Requirement already satisfied: jinja2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (21.3.0)
# Requirement already satisfied: tinycss2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.0.0)
# Requirement already satisfied: bleach in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (5.0.1)
# Requirement already satisfied: defusedxml in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.5.0)
# Requirement already satisfied: markupsafe>=2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.1.1)
# Requirement already satisfied: jupyterlab-pygments in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.7.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.0.4)
# Requirement already satisfied: Mako in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from alembic->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.2.4)
# Requirement already satisfied: soupsieve>1.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from beautifulsoup4->gdown==4.5.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 7)) (2.3.2.post1)
# Requirement already satisfied: cmd2>=1.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (2.4.2)
# Requirement already satisfied: PrettyTable>=0.7.2 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (3.5.0)
# Requirement already satisfied: stevedore>=2.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (4.1.1)
# Requirement already satisfied: autopage>=0.4.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (0.5.1)
# Requirement already satisfied: qtpy>=2.0.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from qtconsole->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from requests->torchvision==0.13.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 4)) (1.7.1)
# Requirement already satisfied: pycparser in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.5->paramiko==2.12.0->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 22)) (2.21)
# Requirement already satisfied: pyperclip>=1.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from cmd2>=1.0.0->cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (3.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.8.3)
# Requirement already satisfied: entrypoints in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.4)
# Requirement already satisfied: jupyter-server>=1.8 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.23.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.2.2)
# Requirement already satisfied: fastjsonschema in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbformat->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from nbformat->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (4.17.0)
# Requirement already satisfied: ptyprocess>=0.5 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.7.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stevedore>=2.0.1->cliff->optuna==3.0.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 25)) (5.11.0)
# Requirement already satisfied: argon2-cffi-bindings in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (21.2.0)
# Requirement already satisfied: webencodings in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.5.1)
# Requirement already satisfied: pure-eval in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.1->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 8)) (2.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (0.19.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (3.6.2)
# Requirement already satisfied: websocket-client in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.4.2)
# Requirement already satisfied: sniffio>=1.1 in /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r /media/rich/Home_Linux_partition/github_repos/ROICaT/requirements_CPU_only.txt (line 21)) (1.3.0)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -illow (/media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages)

# %%
time = current_time.time()

# %%
current_time.ctime()
# Out:
# 'Wed Dec 21 22:03:01 2022'

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(im)
